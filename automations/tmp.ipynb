# %%
import pandas as pd

df = pd.read_json('../public/data/CRWEAPONS-e5ab49/nfts.json', orient='index').reset_index(drop=True)

# %%
tmp = df[df['realPriceAmount'].notnull()]
# tmp.sort_values(by=['starLevel', 'level'], ascending=[False, False])

# %%
for name in tmp['name'].unique():
    tmp2 = tmp[tmp['name'] == name]
    print(tmp2.sort_values('realPriceAmount').head(10).filter(items=['identifier', 'name', 'realPriceAmount', 'starLevel', 'level']))
# Out:
#                  identifier       name  realPriceAmount  starLevel  level
# 2936  CRWEAPONS-e5ab49-1545  Railgun-X         0.023000        2.0    1.0
# 2559  CRWEAPONS-e5ab49-13cc  Railgun-X         0.023333        3.0    1.0
# 2801  CRWEAPONS-e5ab49-14be  Railgun-X         0.030000        2.0    1.0
# 2515  CRWEAPONS-e5ab49-13a0  Railgun-X         0.033000        2.0    1.0
# 2196  CRWEAPONS-e5ab49-1262  Railgun-X         0.033333        3.0    1.0
# 2404  CRWEAPONS-e5ab49-1331  Railgun-X         0.033333        2.0    1.0
# 1686  CRWEAPONS-e5ab49-1024  Railgun-X         0.033333        2.0    1.0
# 2277  CRWEAPONS-e5ab49-12b3  Railgun-X         0.035333        2.0    1.0
# 2805  CRWEAPONS-e5ab49-14c2  Railgun-X         0.043333        2.0    1.0
# 2485  CRWEAPONS-e5ab49-1382  Railgun-X         0.044333        3.0    1.0
#                  identifier         name  realPriceAmount  starLevel  level
# 2607  CRWEAPONS-e5ab49-13fc  Boomstick-X         0.033333        2.0    1.0
# 2698  CRWEAPONS-e5ab49-1457  Boomstick-X         0.033333        2.0    1.0
# 2489  CRWEAPONS-e5ab49-1386  Boomstick-X         0.036667        2.0    1.0
# 2923  CRWEAPONS-e5ab49-1538  Boomstick-X         0.040000        2.0    1.0
# 2552  CRWEAPONS-e5ab49-13c5  Boomstick-X         0.046667        2.0    1.0
# 2714  CRWEAPONS-e5ab49-1467  Boomstick-X         0.046667        2.0    1.0
# 2494  CRWEAPONS-e5ab49-138b  Boomstick-X         0.049667        2.0    1.0
# 2505  CRWEAPONS-e5ab49-1396  Boomstick-X         0.050000        2.0    1.0
# 2955  CRWEAPONS-e5ab49-1558  Boomstick-X         0.053333        3.0    1.0
# 2708  CRWEAPONS-e5ab49-1461  Boomstick-X         0.056667        2.0    1.0
#                  identifier          name  realPriceAmount  starLevel  level
# 2695  CRWEAPONS-e5ab49-1454  Mortar Gun X         0.019600        2.0    1.0
# 2886  CRWEAPONS-e5ab49-1513  Mortar Gun X         0.020000        2.0    1.0
# 2696  CRWEAPONS-e5ab49-1455  Mortar Gun X         0.020000        2.0    1.0
# 2064  CRWEAPONS-e5ab49-11de  Mortar Gun X         0.020667        2.0    1.0
# 2279  CRWEAPONS-e5ab49-12b5  Mortar Gun X         0.020667        2.0    1.0
# 2426  CRWEAPONS-e5ab49-1347  Mortar Gun X         0.021667        3.0    1.0
# 2180  CRWEAPONS-e5ab49-1252  Mortar Gun X         0.022667        2.0    1.0
# 1565  CRWEAPONS-e5ab49-0f5a  Mortar Gun X         0.023000        2.0    1.0
# 2918  CRWEAPONS-e5ab49-1533  Mortar Gun X         0.023000        2.0    1.0
# 2557  CRWEAPONS-e5ab49-13ca  Mortar Gun X         0.023333        2.0    1.0
#                  identifier         name  realPriceAmount  starLevel  level
# 2802  CRWEAPONS-e5ab49-14bf  Tesla Gun X         0.056667        2.0    1.0
# 2937  CRWEAPONS-e5ab49-1546  Tesla Gun X         0.073333        3.0    1.0
# 2849  CRWEAPONS-e5ab49-14ee  Tesla Gun X         0.075000        1.0    1.0
# 1479  CRWEAPONS-e5ab49-0ebd  Tesla Gun X         0.075000        1.0    1.0
# 2794  CRWEAPONS-e5ab49-14b7  Tesla Gun X         0.075000        1.0    1.0
# 2512  CRWEAPONS-e5ab49-139d  Tesla Gun X         0.090000        3.0    1.0
# 2822  CRWEAPONS-e5ab49-14d3  Tesla Gun X         0.090000        2.0    1.0
# 2967  CRWEAPONS-e5ab49-1564  Tesla Gun X         0.091667        3.0    1.0
# 2966  CRWEAPONS-e5ab49-1563  Tesla Gun X         0.093333        2.0    1.0
# 2668  CRWEAPONS-e5ab49-1439  Tesla Gun X         0.100000        3.0    1.0
#                  identifier       name  realPriceAmount  starLevel  level
# 1852  CRWEAPONS-e5ab49-10f6  Blaster-X         0.083333        2.0    1.0
# 1855  CRWEAPONS-e5ab49-10f9  Blaster-X         0.083333        2.0    1.0
# 652   CRWEAPONS-e5ab49-08c0  Blaster-X         0.088667        2.0    4.0
# 2551  CRWEAPONS-e5ab49-13c4  Blaster-X         0.100000        3.0    1.0
# 2685  CRWEAPONS-e5ab49-144a  Blaster-X         0.100000        2.0    1.0
# 2122  CRWEAPONS-e5ab49-1218  Blaster-X         0.100000        3.0    1.0
# 1031  CRWEAPONS-e5ab49-0c81  Blaster-X         0.100000        3.0    1.0
# 2926  CRWEAPONS-e5ab49-153b  Blaster-X         0.100000        1.0    1.0
# 2400  CRWEAPONS-e5ab49-132d  Blaster-X         0.110000        1.0    1.0
# 801   CRWEAPONS-e5ab49-0a55  Blaster-X         0.116667        2.0    1.0

# %%
df.value_counts(['name', 'starLevel']).reset_index().sort_values(by=['name', 'starLevel'], ascending=[True, False])
# Out:
#             name  starLevel  count
# 23     Blaster-X        6.0     35
# 21     Blaster-X        5.0     38
# 17     Blaster-X        4.0     62
# 11     Blaster-X        3.0    140
# 3      Blaster-X        2.0    194
# 14     Blaster-X        1.0     98
# 20   Boomstick-X        6.0     40
# 27   Boomstick-X        5.0     27
# 16   Boomstick-X        4.0     68
# 8    Boomstick-X        3.0    148
# 0    Boomstick-X        2.0    221
# 13   Boomstick-X        1.0    115
# 24  Mortar Gun X        6.0     34
# 28  Mortar Gun X        5.0     26
# 19  Mortar Gun X        4.0     56
# 7   Mortar Gun X        3.0    151
# 1   Mortar Gun X        2.0    220
# 6   Mortar Gun X        1.0    152
# 26     Railgun-X        6.0     27
# 29     Railgun-X        5.0     16
# 18     Railgun-X        4.0     58
# 5      Railgun-X        3.0    153
# 2      Railgun-X        2.0    198
# 10     Railgun-X        1.0    144
# 22   Tesla Gun X        6.0     38
# 25   Tesla Gun X        5.0     32
# 15   Tesla Gun X        4.0     71
# 9    Tesla Gun X        3.0    146
# 4    Tesla Gun X        2.0    182
# 12   Tesla Gun X        1.0    128

# %%
df[df['starLevel'] == 6]
# Out:
#                  identifier        collection          name  \
# 9     CRWEAPONS-e5ab49-0122  CRWEAPONS-e5ab49   Tesla Gun X
# 62    CRWEAPONS-e5ab49-024d  CRWEAPONS-e5ab49     Railgun-X
# 64    CRWEAPONS-e5ab49-0267  CRWEAPONS-e5ab49   Tesla Gun X
# 65    CRWEAPONS-e5ab49-0269  CRWEAPONS-e5ab49   Boomstick-X
# 72    CRWEAPONS-e5ab49-027d  CRWEAPONS-e5ab49     Blaster-X
# ...                     ...               ...           ...
# 2628  CRWEAPONS-e5ab49-1411  CRWEAPONS-e5ab49  Mortar Gun X
# 3020    CRWEAPONS-e5ab49-1e  CRWEAPONS-e5ab49     Railgun-X
# 3030    CRWEAPONS-e5ab49-38  CRWEAPONS-e5ab49   Boomstick-X
# 3041    CRWEAPONS-e5ab49-56  CRWEAPONS-e5ab49   Boomstick-X
# 3043    CRWEAPONS-e5ab49-5a  CRWEAPONS-e5ab49   Boomstick-X
#
#                                                     url  \
# 9     https://media.elrond.com/nfts/asset/bafybeibrx...
# 62    https://media.elrond.com/nfts/asset/bafybeibrx...
# 64    https://media.elrond.com/nfts/asset/bafybeibrx...
# 65    https://media.elrond.com/nfts/asset/bafybeibrx...
# 72    https://media.elrond.com/nfts/asset/bafybeibrx...
# ...                                                 ...
# 2628  https://media.elrond.com/nfts/asset/bafybeibrx...
# 3020  https://media.elrond.com/nfts/asset/bafybeibrx...
# 3030  https://media.elrond.com/nfts/asset/bafybeibrx...
# 3041  https://media.elrond.com/nfts/asset/bafybeibrx...
# 3043  https://media.elrond.com/nfts/asset/bafybeibrx...
#
#                                            thumbnailUrl  \
# 9     https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 62    https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 64    https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 65    https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 72    https://media.elrond.com/nfts/thumbnail/CRWEAP...
# ...                                                 ...
# 2628  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 3020  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 3030  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 3041  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 3043  https://media.elrond.com/nfts/thumbnail/CRWEAP...
#
#                                                   owner  rank priceCurrency  \
# 9     erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
# 62    erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
# 64    erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
# 65    erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
# 72    erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
# ...                                                 ...   ...           ...
# 2628  erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
# 3020  erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
# 3030  erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
# 3041  erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
# 3043  erd1qqqqqqqqqqqqqpgq5dz6p0nsz35sht95kp6vjrznff...   NaN          None
#
#       priceAmount        xp   wear  level  starLevel  damage  reloadTime  \
# 9             NaN  121200.0  100.0   17.0        6.0  2800.0        2.70
# 62            NaN    1212.0    9.0   20.0        6.0  2862.0        2.40
# 64            NaN   72010.0  100.0   20.0        6.0  3100.0        2.70
# 65            NaN   12823.0   65.5   20.0        6.0  4704.0        2.10
# 72            NaN  121200.0  100.0   20.0        6.0  4090.0        2.75
# ...           ...       ...    ...    ...        ...     ...         ...
# 2628          NaN       0.0    0.0   20.0        6.0  3357.0        3.00
# 3020          NaN   75074.0  100.0   16.0        6.0  2470.0        2.40
# 3030          NaN  127107.0  100.0   20.0        6.0  4704.0        2.10
# 3041          NaN  219966.0  100.0   20.0        6.0  4704.0        2.10
# 3043          NaN  112181.0  100.0   18.0        6.0  4472.0        2.10
#
#       ammo  range  realPriceAmount
# 9      2.0    9.5              NaN
# 62     2.0   11.0              NaN
# 64     2.0    9.5              NaN
# 65     3.0    9.0              NaN
# 72     3.0   10.5              NaN
# ...    ...    ...              ...
# 2628   3.0    9.0              NaN
# 3020   2.0   11.0              NaN
# 3030   3.0    9.0              NaN
# 3041   3.0    9.0              NaN
# 3043   3.0    9.0              NaN
#
# [174 rows x 18 columns]

# %%
# for each name, plot heatmap of starLevel vs level (there are 6 starLevels and 20 levels)
# display all the possible combinations of starLevel and level
# and count the number of occurrences of each combination

import matplotlib.pyplot as plt
import seaborn as sns

tmp = df[df['starLevel'].notna() & df['level'].notna()]
tmp['starLevel'] = tmp['starLevel'].astype(int)
tmp['level'] = tmp['level'].astype(int)
for name in df['name'].unique():
    tmp2 = tmp[tmp['name'] == name]
    d = tmp2.groupby(['starLevel', 'level']).size().to_dict()
    for i in range(6):
        for j in range(20):
            starLevel = i + 1
            level = j + 1
            if (starLevel, level) not in d:
                d[(starLevel, level)] = 0
    sns.heatmap(pd.Series(d).unstack(fill_value=0), annot=True, fmt='d')
    plt.title(name)
    plt.show()
# Out:
# /tmp/ipykernel_12257/1737912879.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['starLevel'] = tmp['starLevel'].astype(int)
# /tmp/ipykernel_12257/1737912879.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['level'] = tmp['level'].astype(int)

# %%
tmp.sort_values(by=['starLevel', 'level'], ascending=[False, False]).head(20)
# Out:
#                  identifier        collection          name  \
# 1566  CRWEAPONS-e5ab49-0f5b  CRWEAPONS-e5ab49   Tesla Gun X
# 881   CRWEAPONS-e5ab49-0b2b  CRWEAPONS-e5ab49  Mortar Gun X
# 39    CRWEAPONS-e5ab49-01f1  CRWEAPONS-e5ab49  Mortar Gun X
# 1475  CRWEAPONS-e5ab49-0eaf  CRWEAPONS-e5ab49   Boomstick-X
# 1514    CRWEAPONS-e5ab49-0f  CRWEAPONS-e5ab49     Railgun-X
# 1553  CRWEAPONS-e5ab49-0f4b  CRWEAPONS-e5ab49     Blaster-X
# 3049    CRWEAPONS-e5ab49-6b  CRWEAPONS-e5ab49  Mortar Gun X
# 2256  CRWEAPONS-e5ab49-129e  CRWEAPONS-e5ab49     Railgun-X
# 250   CRWEAPONS-e5ab49-050c  CRWEAPONS-e5ab49     Railgun-X
# 911   CRWEAPONS-e5ab49-0b92  CRWEAPONS-e5ab49  Mortar Gun X
# 2300  CRWEAPONS-e5ab49-12ca  CRWEAPONS-e5ab49   Tesla Gun X
# 665   CRWEAPONS-e5ab49-08e7  CRWEAPONS-e5ab49  Mortar Gun X
# 1251  CRWEAPONS-e5ab49-0dba  CRWEAPONS-e5ab49  Mortar Gun X
# 904   CRWEAPONS-e5ab49-0b79  CRWEAPONS-e5ab49  Mortar Gun X
# 199   CRWEAPONS-e5ab49-044c  CRWEAPONS-e5ab49  Mortar Gun X
# 106   CRWEAPONS-e5ab49-02fe  CRWEAPONS-e5ab49     Blaster-X
# 992   CRWEAPONS-e5ab49-0c43  CRWEAPONS-e5ab49  Mortar Gun X
# 507   CRWEAPONS-e5ab49-07d5  CRWEAPONS-e5ab49     Railgun-X
# 1914  CRWEAPONS-e5ab49-113e  CRWEAPONS-e5ab49  Mortar Gun X
# 943   CRWEAPONS-e5ab49-0bd4  CRWEAPONS-e5ab49     Railgun-X
#
#                                                     url  \
# 1566  https://media.elrond.com/nfts/asset/bafybeibrx...
# 881   https://media.elrond.com/nfts/asset/bafybeibrx...
# 39    https://media.elrond.com/nfts/asset/bafybeibrx...
# 1475  https://media.elrond.com/nfts/asset/bafybeibrx...
# 1514  https://media.elrond.com/nfts/asset/bafybeibrx...
# 1553  https://media.elrond.com/nfts/asset/bafybeibrx...
# 3049  https://media.elrond.com/nfts/asset/bafybeibrx...
# 2256  https://media.elrond.com/nfts/asset/bafybeibrx...
# 250   https://media.elrond.com/nfts/asset/bafybeibrx...
# 911   https://media.elrond.com/nfts/asset/bafybeibrx...
# 2300  https://media.elrond.com/nfts/asset/bafybeibrx...
# 665   https://media.elrond.com/nfts/asset/bafybeibrx...
# 1251  https://media.elrond.com/nfts/asset/bafybeibrx...
# 904   https://media.elrond.com/nfts/asset/bafybeibrx...
# 199   https://media.elrond.com/nfts/asset/bafybeibrx...
# 106   https://media.elrond.com/nfts/asset/bafybeibrx...
# 992   https://media.elrond.com/nfts/asset/bafybeibrx...
# 507   https://media.elrond.com/nfts/asset/bafybeibrx...
# 1914  https://media.elrond.com/nfts/asset/bafybeibrx...
# 943   https://media.elrond.com/nfts/asset/bafybeibrx...
#
#                                            thumbnailUrl  \
# 1566  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 881   https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 39    https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 1475  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 1514  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 1553  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 3049  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 2256  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 250   https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 911   https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 2300  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 665   https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 1251  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 904   https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 199   https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 106   https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 992   https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 507   https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 1914  https://media.elrond.com/nfts/thumbnail/CRWEAP...
# 943   https://media.elrond.com/nfts/thumbnail/CRWEAP...
#
#                                                   owner  rank priceCurrency  \
# 1566  erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 881   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 39    erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 1475  erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 1514  erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 1553  erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 3049  erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 2256  erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 250   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 911   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 2300  erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 665   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 1251  erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 904   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 199   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 106   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 992   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 507   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 1914  erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
# 943   erd1qqqqqqqqqqqqqpgq6wegs2xkypfpync8mn2sa5cmpq...   NaN          EGLD
#
#       priceAmount        xp   wear  level  starLevel  damage  reloadTime  \
# 1566         7.00  109848.0  100.0   19.0        5.0  2640.0        2.70
# 881          3.20   72489.0  100.0   15.0        5.0  2436.0        3.00
# 39           3.20   41790.0  100.0   10.0        5.0  2066.0        3.00
# 1475         5.00   29233.0   36.9   10.0        5.0  3265.0        2.10
# 1514         5.00   60018.0  100.0   10.0        5.0  1666.0        2.40
# 1553         6.50   22670.0   75.2   10.0        5.0  2720.0        2.75
# 3049         8.90   15916.0   12.4    9.0        5.0  1992.0        3.00
# 2256         4.27    7842.0    0.4    8.0        5.0  1518.0        2.40
# 250          3.00   42793.0   24.9   12.0        4.0  1638.0        2.40
# 911          6.00   26966.0   72.5   10.0        4.0  1913.0        3.00
# 2300         3.50   18737.0   39.9   10.0        4.0  1540.0        2.70
# 665          2.50   41562.0  100.0    9.0        4.0  1856.0        3.00
# 1251         0.90   13859.0   67.5    9.0        4.0  1856.0        3.00
# 904          2.45    9588.0   42.1    8.0        4.0  1799.0        3.00
# 199          2.89    6120.0   12.9    7.0        4.0  1742.0        3.00
# 106          4.50    1257.0    3.4    5.0        4.0  1940.0        2.75
# 992          9.00    2245.0    1.9    5.0        4.0  1628.0        3.00
# 507          1.00     984.0    3.1    4.0        4.0  1174.0        2.40
# 1914         0.90    1004.0    3.0    4.0        4.0  1571.0        3.00
# 943          1.50       0.0    0.0    1.0        4.0  1000.0        2.40
#
#       ammo  range  realPriceAmount
# 1566   2.0    9.5         0.583333
# 881    3.0    9.0         0.266667
# 39     3.0    9.0         0.266667
# 1475   3.0    9.0         0.416667
# 1514   2.0   10.5         0.416667
# 1553   3.0   10.5         0.541667
# 3049   3.0    9.0         0.741667
# 2256   2.0   10.5         0.355833
# 250    2.0   10.5         0.333333
# 911    3.0    8.5         0.666667
# 2300   2.0    9.5         0.388889
# 665    3.0    8.5         0.277778
# 1251   3.0    8.5         0.100000
# 904    3.0    8.5         0.272222
# 199    3.0    8.5         0.321111
# 106    3.0   10.5         0.500000
# 992    3.0    8.5         1.000000
# 507    2.0   10.5         0.111111
# 1914   3.0    8.5         0.100000
# 943    2.0   10.5         0.166667

# %%
import matplotlib.pyplot as plt

for name in tmp['name'].unique():
    # plot cdf of realPriceAmount
    cdf = tmp[tmp['name'] == name]['realPriceAmount'].value_counts().sort_index().cumsum()
    cdf = cdf / cdf.max()
    cdf.plot(label=name)
plt.legend()
plt.title('CDF of realPriceAmount')
plt.show()
